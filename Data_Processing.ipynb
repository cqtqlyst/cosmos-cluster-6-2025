# %%
import pandas as pd

# Create the data manually from your text
data = [
    [1, 'SRR20325464', 'GSM6356089', 'Healthy', 'Vastus lateralis', 'Control', 'Healthy_Control', 'Strength'],
    [2, 'SRR20325465', 'GSM6356088', 'Healthy', 'Vastus lateralis', 'Control', 'Healthy_Control', 'Strength'],
    [3, 'SRR20325466', 'GSM6356087', 'Healthy', 'Vastus lateralis', 'Control', 'Healthy_Control', 'Strength'],
    [4, 'SRR20325467', 'GSM6356085', 'Healthy', 'Vastus lateralis', 'Control', 'Healthy_Control', 'Strength'],
    [5, 'SRR20325468', 'GSM6356083', 'DM1', 'Vastus lateralis', 'Post', 'DM1_Post', 'Strength'],
    [6, 'SRR20325469', 'GSM6356082', 'DM1', 'Vastus lateralis', 'Pre', 'DM1_Pre', 'Strength'],
    [7, 'SRR20325470', 'GSM6356084', 'Healthy', 'Vastus lateralis', 'Control', 'Healthy_Control', 'Strength'],
    [8, 'SRR20325471', 'GSM6356086', 'Healthy', 'Vastus lateralis', 'Control', 'Healthy_Control', 'Strength'],
    [9, 'SRR20325472', 'GSM6356081', 'DM1', 'Vastus lateralis', 'Post', 'DM1_Post', 'Strength'],
    [10, 'SRR20325473', 'GSM6356080', 'DM1', 'Vastus lateralis', 'Pre', 'DM1_Pre', 'Strength'],
    [11, 'SRR20325474', 'GSM6356078', 'DM1', 'Vastus lateralis', 'Pre', 'DM1_Pre', 'Strength'],
    [12, 'SRR20325475', 'GSM6356076', 'DM1', 'Vastus lateralis', 'Pre', 'DM1_Pre', 'Strength'],
    [13, 'SRR20325476', 'GSM6356075', 'DM1', 'Vastus lateralis', 'Post', 'DM1_Post', 'Strength'],
    [14, 'SRR20325477', 'GSM6356077', 'DM1', 'Vastus lateralis', 'Post', 'DM1_Post', 'Strength'],
    [15, 'SRR20325478', 'GSM6356079', 'DM1', 'Vastus lateralis', 'Post', 'DM1_Post', 'Strength'],
    [16, 'SRR20325479', 'GSM6356074', 'DM1', 'Vastus lateralis', 'Pre', 'DM1_Pre', 'Strength'],
    [17, 'SRR20325480', 'GSM6356073', 'DM1', 'Vastus lateralis', 'Post', 'DM1_Post', 'Strength'],
    [18, 'SRR20325481', 'GSM6356071', 'DM1', 'Vastus lateralis', 'Post', 'DM1_Post', 'Strength'],
    [19, 'SRR20325482', 'GSM6356069', 'DM1', 'Vastus lateralis', 'Post', 'DM1_Post', 'Strength'],
    [20, 'SRR20325483', 'GSM6356068', 'DM1', 'Vastus lateralis', 'Pre', 'DM1_Pre', 'Strength'],
    [21, 'SRR20325484', 'GSM6356070', 'DM1', 'Vastus lateralis', 'Pre', 'DM1_Pre', 'Strength'],
    [22, 'SRR20325485', 'GSM6356072', 'DM1', 'Vastus lateralis', 'Pre', 'DM1_Pre', 'Strength'],
    [23, 'SRR20325486', 'GSM6356067', 'DM1', 'Vastus lateralis', 'Post', 'DM1_Post', 'Strength'],
    [24, 'SRR20325487', 'GSM6356066', 'DM1', 'Vastus lateralis', 'Pre', 'DM1_Pre', 'Strength'],
    [25, 'SRR16104009', 'GSM5602348', 'Healthy', '', 'Control', 'Healthy_Control', 'Aerobic'],
    [26, 'SRR16104011', 'GSM5602349', 'Healthy', '', 'Control', 'Healthy_Control', 'Aerobic'],
    [27, 'SRR16104013', 'GSM5602350', 'Healthy', '', 'Control', 'Healthy_Control', 'Aerobic'],
    [28, 'SRR16104015', 'GSM5602351', 'Healthy', '', 'Control', 'Healthy_Control', 'Aerobic'],
    [29, 'SRR16104017', 'GSM5602352', 'Healthy', '', 'Control', 'Healthy_Control', 'Aerobic'],
    [30, 'SRR16104019', 'GSM5602353', 'Healthy', '', 'Control', 'Healthy_Control', 'Aerobic'],
    [31, 'SRR16104021', 'GSM5602354', 'Healthy', '', 'Control', 'Healthy_Control', 'Aerobic'],
    [32, 'SRR16104023', 'GSM5602355', 'Healthy', '', 'Control', 'Healthy_Control', 'Aerobic'],
    [33, 'SRR16104025', 'GSM5602356', 'Healthy', '', 'Control', 'Healthy_Control', 'Aerobic'],
    [34, 'SRR16104027', 'GSM5602357', 'Healthy', '', 'Control', 'Healthy_Control', 'Aerobic'],
    [35, 'SRR16104029', 'GSM5602358', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [36, 'SRR16104033', 'GSM5602359', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [37, 'SRR16104037', 'GSM5602360', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [38, 'SRR16104041', 'GSM5602361', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [39, 'SRR16104045', 'GSM5602362', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [40, 'SRR16104049', 'GSM5602363', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [41, 'SRR16104053', 'GSM5602364', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [42, 'SRR16104055', 'GSM5602365', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [43, 'SRR16104057', 'GSM5602366', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [44, 'SRR16104061', 'GSM5602367', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [45, 'SRR16104065', 'GSM5602368', 'DM1', '', 'Post', 'DM1_Post', 'Aerobic'],
    [46, 'SRR16104069', 'GSM5602369', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic'],
    [47, 'SRR16104073', 'GSM5602370', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic'],
    [48, 'SRR16104077', 'GSM5602371', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic'],
    [49, 'SRR16104081', 'GSM5602372', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic'],
    [50, 'SRR16104085', 'GSM5602373', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic'],
    [51, 'SRR16104089', 'GSM5602374', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic'],
    [52, 'SRR16104093', 'GSM5602375', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic'],
    [53, 'SRR16104095', 'GSM5602376', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic'],
    [54, 'SRR16104097', 'GSM5602377', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic'],
    [55, 'SRR16104101', 'GSM5602378', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic'],
    [56, 'SRR16104105', 'GSM5602379', 'DM1', '', 'Pre', 'DM1_Pre', 'Aerobic']
]

# Create DataFrame
columns = ['index', 'Run', 'Sample Name', 'genotype', 'tissue', 'treatment', 'genotype_treatment', 'dataset']
metadata_combined = pd.DataFrame(data, columns=columns)

# Save to CSV
metadata_combined.to_csv('metadata_combined.csv', index=False)
print("Metadata saved to 'metadata_combined.csv'")

# Display first few rows to verify
print("\nFirst 5 rows:")
print(metadata_combined.head())

# Display summary
print(f"\nDataFrame shape: {metadata_combined.shape}")
print(f"Columns: {metadata_combined.columns.tolist()}")
# Out:
# Metadata saved to 'metadata_combined.csv'
#
# First 5 rows:
#    index          Run Sample Name genotype            tissue treatment  \
# 0      1  SRR20325464  GSM6356089  Healthy  Vastus lateralis   Control
# 1      2  SRR20325465  GSM6356088  Healthy  Vastus lateralis   Control
# 2      3  SRR20325466  GSM6356087  Healthy  Vastus lateralis   Control
# 3      4  SRR20325467  GSM6356085  Healthy  Vastus lateralis   Control
# 4      5  SRR20325468  GSM6356083      DM1  Vastus lateralis      Post
#
#   genotype_treatment   dataset
# 0    Healthy_Control  Strength
# 1    Healthy_Control  Strength
# 2    Healthy_Control  Strength
# 3    Healthy_Control  Strength
# 4           DM1_Post  Strength
#
# DataFrame shape: (56, 8)
# Columns: ['index', 'Run', 'Sample Name', 'genotype', 'tissue', 'treatment', 'genotype_treatment', 'dataset']
